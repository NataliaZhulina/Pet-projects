# %% [markdown]
# <a href="https://colab.research.google.com/github/NataliaZhulina/Pet-projects/blob/main/%22sydney_streets_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install osmnx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.5/107.5 kB 3.6 MB/s eta 0:00:00
# ...

# %%
import osmnx as ox

# %%
admin = ox.geocode_to_gdf('Sydney,Canada')
admin_poly = admin.geometry.values[0]
admin_poly
# Out:
# <POLYGON ((-60.216 46.118, -60.214 46.117, -60.214 46.116, -60.213 46.116, -...>

# %%
G = ox.graph_from_polygon(admin_poly)

# %%
G.number_of_nodes(), G.number_of_edges
# Out:
# (1431,
#  <bound method MultiGraph.number_of_edges of <networkx.classes.multidigraph.MultiDiGraph object at 0x7bcd93481060>>)

# %%
nodes, edges = ox.graph_to_gdfs(G)

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
f, ax = plt.subplots(1, figsize=(10, 10))
edges.plot(ax=ax, edgecolor = 'orange', linewidth = 0.3)
ax.set_title("Sydney, Nova Scotia", fontsize=20, color='white')
ax.axis('off')
# Out:
# (-60.2118942, -60.1448646, 46.105487705, 46.180056595)

# %%
# Сохранение визуализации
output_path = 'Sydney_street_network.png'
f.savefig(output_path, dpi=300, bbox_inches='tight', facecolor=f.get_facecolor())

from google.colab import files
files.download(output_path)
